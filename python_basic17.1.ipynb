# %%
def evenlyd(a,b,c):
    d = 0
    if a ==1:
        e=2
    for i in range(e,b+1):

        if i%c==0:
            d = d+i
    return d


        
a = int(input("enter value of a: "))
b = int(input("enter value of b: "))
c = int(input("enter value of c: "))

d = evenlyd(a,b,c)

if d%2 == 0:
    print("evenly divisible")
else:
    print("No evenly divisible")
# Out:
# enter value of a: 1
# enter value of b: 10
# enter value of c: 2
# evenly divisible
