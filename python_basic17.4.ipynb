# %%
def factorial(a):
    
    
    if a==1:
        return a
    else:
        return a * factorial(a-1)  

a = int(input("enter a number : ") )
b = factorial(a)
print(f"factorial {a} is : ",b)
# Out:
# factorial 5 is :  120
