# %%
def replace_vowels(a,b):
    c=['a','e','i','o','u']
    d=''
    for i in a:
        if i in c:
            i=b
            d=d+i
        else:
            d=d+i
    return d
a = input("enter string : ")
b = input("enter character: ")
r = replace_vowels(a, b) 
print(r)
# Out:
# enter string : pawan jadhav
# enter character: @
# p@w@n j@dh@v
